# %%
from generator import ImageGenerator # type: ignore
import numpy as np  # type: ignore
import matplotlib.pyplot as plt 
import random
from skimage.transform import resize

# %%
file_path ="data\exercise_data"
label_path = "data\Labels.json"
batch_size = 12
image_size = [32, 32,3]
rotation=False
mirroring=False 
shuffle=False
a = ImageGenerator(file_path,label_path,batch_size,image_size,rotation, mirroring, shuffle)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-8d93c7e6c941> in <module>
#       6 mirroring=False
#       7 shuffle=False
# ----> 8 a = ImageGenerator(file_path,label_path,batch_size,image_size,rotation, mirroring, shuffle)
#
# c:\Users\Niloufar\Desktop\DEEP LEARNING\exercise0_material\src_to_implement\generator.py in __init__(self, file_path, label_path, batch_size, image_size, rotation, mirroring, shuffle)
#      33         self.pointer = 0
#      34         self.mirroring_or_rotating = None
# ---> 35         self.img_list = os.listdir(self.file_path)
#      36         self.img_list_back_up = list()
#      37         self.imgs_in_one_batch = list()
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'data\\data\\exercise_data'

# %%
x,y= a.next()
print(len(x))
print(len(a.img_list))
print(len(a.img_list_back_up))
print(a.current_epoch())
# Out:
# 12
# 40
# 60
# 5

# %%
a.show()

# %%
def augment(img):
    modified_img = []
    global mirroring_or_rotating
    if  mirroring_or_rotating == 1:
        modified_img = np.fliplr(img)
        mirroring_or_rotating = []
        
    if mirroring_or_rotating == 0:
        random = np.random.choice(["rotation_90","rotation_180","rotation_270"])
        if random == "rotation_90":
            modified_img = np.rot90(img)

        elif random == "rotation_180":
            modified_img = np.rot90(img,2)

        elif random == "rotation_270":
            modified_img = np.rot90(img,3)
        
        
    return np.array(modified_img)

# %%
self.assertFalse(np.any(np.all(sample == b1_without_sample,
                         axis=(1, 2, 3))),
                         msg="Possible error: One or more samples appear more than once in the first batch (even for non-"
                         "overlapping batches. Please make sure that all samples are unique within the batch.")
self.assertFalse(np.any(np.all(sample == b2[0],
                         axis=(1, 2, 3))),
                         msg="Possible error: One or more samples appear more than once in the following batches"
                         "(even for non-overlapping batches. Please make sure that all samples are unique within "
                         "the batch."
                         )
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-22-b5391fe483d1> in <module>
#       2 file_path = './Labels.json'
#       3 label_path = './exercise_data/'
# ----> 4 gen = ImageGenerator(file_path, label_path, 12, [32, 32, 3], rotation=False, mirroring=False,
#       5                              shuffle=False)
#       6 gen2 = ImageGenerator(file_path, label_path, 12, [32, 32, 3], rotation=False, mirroring=False,
#
# c:\Users\Niloufar\Desktop\DEEP LEARNING\exercise0_material\src_to_implement\generator.py in __init__(self, file_path, label_path, batch_size, image_size, rotation, mirroring, shuffle)
#      33         self.pointer = 0
#      34         self.mirroring_or_rotating = None
# ---> 35         self.img_list = os.listdir(self.file_path)
#      36         self.img_list_back_up = list()
#      37         self.imgs_in_one_batch = list()
#
# ...

# %%
import os.path
import json
from os import listdir
import numpy as np 
from generator import ImageGenerator

label_path = './Labels.json'
file_path = './exercise_data/'

gen = ImageGenerator(file_path, label_path, 50, [32, 32, 3], rotation=False, mirroring=False, shuffle=True)
gen.next()
gen.next()









gen.current_epoch()
# Out:
# 0

# %%
from generator import ImageGenerator
gen = ImageGenerator(self.file_path, self.label_path, 50, [32, 32, 3], rotation=False, mirroring=False,
                             shuffle=True)
gen.next()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d0e6b4482e44> in <module>
#       1 from generator import ImageGenerator
# ----> 2 gen = ImageGenerator(self.file_path, self.label_path, 50, [32, 32, 3], rotation=False, mirroring=False,
#       3                              shuffle=True)
#       4 gen.next()
#
# NameError: name 'self' is not defined

# %%
from generator import ImageGenerator
label_path = './Labels.json'
file_path = './exercise_data/'
gen = ImageGenerator(file_path, label_path, 50, [32, 32, 3], rotation=False, mirroring=False,
                             shuffle=False)
b1 = gen.next()
b2 = gen.next()
sample_index = np.random.choice(np.arange(50))
sample = b1[0][sample_index]
b1_without_sample = np.delete(b1[0], sample_index, axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a5e5ca3b23c2> in <module>
#       6 b1 = gen.next()
#       7 b2 = gen.next()
# ----> 8 sample_index = np.random.choice(np.arange(50))
#       9 sample = b1[0][sample_index]
#      10 b1_without_sample = np.delete(b1[0], sample_index, axis=0)
#
# NameError: name 'np' is not defined

# %%
import numpy
import PIL
 
# Convert Image to array
img = PIL.Image.open("foo.jpg").convert("L")
arr = numpy.array(img)
 
# Convert array to Image
img = PIL.Image.fromarray(arr)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-196dd1934187> in <module>
#       3
#       4 # Convert Image to array
# ----> 5 img = PIL.Image.open("foo.jpg").convert("L")
#       6 arr = numpy.array(img)
#       7
#
# c:\Users\Niloufar\anaconda3\envs\deep_learning\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    3275
#    3276     if filename:
# -> 3277         fp = builtins.open(filename, "rb")
#    3278         exclusive_fp = True
#    3279
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Niloufar\\Desktop\\DEEP LEARNING\\exercise0_material\\src_to_implement\\foo.jpg'
